# %% [markdown]
# <a href="https://colab.research.google.com/github/te19oishi/colab/blob/main/correlate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.matlib as mlb
import numpy.linalg as nla
import scipy.signal as ss
import cis

# %%
# !pip install simpleaudio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
y=[0,2,2,0,-2,0,2,2,0,-2,0]
yc=np.correlate(y,y,'full')
plt.plot(yc)
plt.show()

# %%
y=[0,2,2,0,-2,0,2,2,0,-2,0]
yc=np.correlate(y,y,'full')
plt.plot(yc/25)
plt.show()

# %%
y,fs=cis.wavread('a-.wav')
plt.plot(y)
plt.show()
a=y[2000:3024]
plt.plot(a)
plt.show()
ac=np.correlate(a,a,'full')
plt.plot(np.arange(1023-100,1023+101),ac[1023-100:1023+101])
plt.show()
fs
# Out:
# 8000

# %%
x=np.arange(1,10)*2
x
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14, 16, 18])

# %%
ind=np.array([[0,2,4,6],[1,3,5,7],[2,4,6,8]])
ind
# Out:
# array([[0, 2, 4, 6],
#        [1, 3, 5, 7],
#        [2, 4, 6, 8]])

# %%
F = x[ind]
F
# Out:
# array([[ 2,  6, 10, 14],
#        [ 4,  8, 12, 16],
#        [ 6, 10, 14, 18]])

# %%
F[:,0]
# Out:
# array([2, 4, 6])

# %%
F[:,1]
# Out:
# array([ 6,  8, 10])

# %%
F[2,2]
# Out:
# 14

# %%
W=3
N=4
SP=2
np.array([np.arange(0,W)]).T+np.array([np.arange(0,N)])*SP
# Out:
# array([[0, 2, 4, 6],
#        [1, 3, 5, 7],
#        [2, 4, 6, 8]])

# %%
np.array([np.arange(0,W)]).T
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
np.array([np.arange(0,N)])*SP
# Out:
# array([[0, 2, 4, 6]])
