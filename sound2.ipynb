# %% [markdown]
# <a href="https://colab.research.google.com/github/te19oishi/colab/blob/main/sound2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display

# %%
t=np.arange(0,1/2,1/16000)
a=0.8
f=523
y=a*np.cos(2*np.pi*f*t)

# %%
y
# Out:
# array([ 0.8       ,  0.78318658,  0.73345306, ..., -0.6528899 ,
#        -0.73345306, -0.78318658])

# %%
IPython.display.Audio(y,rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
