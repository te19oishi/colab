# %% [markdown]
# <a href="https://colab.research.google.com/github/te19oishi/colab/blob/main/sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display

# %%
t=np.arange(0,1/2,1/8000)
a=0.8
f=262
y=a*np.sin(2*np.pi*f*t)

# %%
y
# Out:
# array([ 0.        ,  0.16346016,  0.32002331, ..., -0.46308343,
#        -0.32002331, -0.16346016])

# %%
IPython.display.Audio(y,rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
t=np.arange(0,2,1/8000)
a=0.8
f=440
y=a*np.sin(2*np.pi*f*t)

# %%
y
# Out:
# array([ 0.        ,  0.27099034,  0.50993919, ..., -0.68859362,
#        -0.50993919, -0.27099034])

# %%
IPython.display.Audio(y,rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
